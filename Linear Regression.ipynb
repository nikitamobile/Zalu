# %%
import pandas as pd

# %%
data = pd.read_csv("FL/Fish.csv")
data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
data.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
data_=data.loc[:,['Weight','Length3']]
data_.head(5)
# Out:
#    Weight  Length3
# 0   242.0     30.0
# 1   290.0     31.2
# 2   340.0     31.1
# 3   363.0     33.5
# 4   430.0     34.0

# %%
import matplotlib.pyplot as plt

# %%
data.plot(x='Length3',y = 'Weight', style = 'o')
plt.xlabel('Length3')
plt.ylabel('Weight')
plt.show()

# %%
plt.scatter(x = 'Length3', y = 'Weight')
# Out:
# Text(0.5, 0, 'Length3')

# %%
X = pd.DataFrame(data['Length3'])
y = pd.DataFrame(data['Weight'])

# %%
X.size, y.size
# Out:
# (159, 159)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.2, random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (127, 1)
# (32, 1)
# (127, 1)
# (32, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# [-466.0721266]

# %%
print(regressor.coef_)
# Out:
# [[27.61954153]]

# %%
y_pred = regressor.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred
# Out:
#       Predicted
# 0    710.520343
# 1    188.511008
# 2    561.374818
# 3    196.796870
# 4    113.938246
# 5    602.804131
# 6    205.082733
# 7    533.755277
# 8    163.653420
# 9    238.226183
# 10   182.987099
# 11   210.606641
# 12   -60.064866
# 13   332.132624
# 14   627.661718
# 15   182.987099
# 16   174.701237
# 17   500.611827
# 18   406.705386
# 19   279.655495
# 20  -101.494178
# 21   -18.635554
# 22   304.513082
# 23   492.325965
# 24   155.367558
# 25   749.187701
# 26   591.756314
# 27  -167.781078
# 28  1301.578532
# 29   202.320779
# 30   820.998509
# 31   332.132624

# %%
y_test
# Out:
#      Weight
# 29   1000.0
# 42    120.0
# 14    600.0
# 91    130.0
# 81     85.0
# 19    650.0
# 44    145.0
# 11    500.0
# 40      0.0
# 97    145.0
# 89    135.0
# 94    150.0
# 73     32.0
# 105   250.0
# 59    800.0
# 90    110.0
# 66    140.0
# 54    390.0
# 108   320.0
# 100   197.0
# 153     9.8
# 35     40.0
# 51    180.0
# 5     450.0
# 84    125.0
# 31    955.0
# 16    700.0
# 145     6.7
# 143  1550.0
# 93    145.0
# 127  1000.0
# 103   260.0

# %%
X_test
# Out:
#      Length3
# 29      42.6
# 42      23.7
# 14      37.2
# 91      24.0
# 81      21.0
# 19      38.7
# 44      24.3
# 11      36.2
# 40      22.8
# 97      25.5
# 89      23.5
# 94      24.5
# 73      14.7
# 105     28.9
# 59      39.6
# 90      23.5
# 66      23.2
# 54      35.0
# 108     31.6
# 100     27.0
# 153     13.2
# 35      16.2
# 51      27.9
# 5       34.7
# 84      22.5
# 31      44.0
# 16      38.3
# 145     10.8
# 143     64.0
# 93      24.2
# 127     46.6
# 103     28.9
